# %%
import pandas as pd
import logging
import os
from sqlalchemy import create_engine
import time

# %%
for file in os.listdir('data'):
    if '.csv' in file:
        df = pd.read_csv('data/'+file)
        print(df.shape)
# Out:
# (206529, 9)
# (224489, 9)
# (2372474, 16)
# (12261, 9)
# (12825363, 14)
# (5543, 10)

# %%
logging.basicConfig(
    filename="logs/ingestion_db.log", 
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s", 
    filemode="a"  
)

engine = create_engine('sqlite:///inventory.db')

def ingest_db(df, table_name, engine):
    '''this function will ingest the dataframe into database table'''
    df.to_sql(table_name, con = engine, if_exists = 'replace', index = False)
    
def load_raw_data():
    '''this function will load the CSVs as dataframe and ingest into db'''
    start = time.time()
    for file in os.listdir('data'):
        if '.csv' in file:
            df = pd.read_csv('data/'+file)
            logging.info(f'Ingesting {file} in db')
            ingest_db(df, file[:-4], engine)
    end = time.time()
    total_time = (end - start)/60
    logging.info('--------------Ingestion Complete------------')
    
    logging.info(f'\nTotal Time Taken: {total_time} minutes')

if __name__ == '__main__':
    load_raw_data()

# %%
import os

for file in os.listdir("data"):
    path = os.path.join("data", file)
    print(file, os.path.getsize(path)/(1024*1024))
# Out:
# .ipynb_checkpoints 0.0
# begin_inventory.csv 16.63944149017334
# end_inventory.csv 18.104559898376465
# purchases.csv 344.8250789642334
# purchase_prices.csv 0.9989194869995117
# sales.csv 1522.764310836792
# vendor_invoice.csv 0.48630428314208984
